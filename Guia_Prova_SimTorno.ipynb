# %% [markdown]
# #  Guia - SimTorno (Prova de CNC)
# Tudo que você precisa para a prova. Use `Ctrl + F` para buscar comandos
#
# ---
#
# ## 1. Resumo de Comandos (Apostila da Professora)
#
# ### Funções Especiais e de Posicionamento
# * **# ( End of Block):** Finaliza o bloco ou sentença.
# * **X / Z:** Eixo transversal (X) e eixo longitudinal (Z).
# * **I / K:** Coordenadas de centro de arco (I para eixo X, K para eixo Z).
# * **R:** Definição de raio.
# * **N:** Identifica cada bloco ou sentença de informação.
# * **T:** Seleciona as ferramentas na torre. A função `T00` cancela os corretores e determina o Ponto de Troca.
# * **F:** Programa a velocidade de avanço para o trabalho em usinagem.
# * **S:** Fornece o valor da velocidade de corte.
# * **H:** Executa desvios incondicionais no programa.
# * **P:** Identifica programas e sub-programas.
# * **L:** Define o número de repetições de uma operação.
# * **/** (Barra): Inibe a execução de blocos no programa.
#
# ###  Códigos Preparatórios (Funções G)
# * **G00:** avanço rápido.
# * **G01:** Interpolação linear com avanço programado.
# * **G02:** Interpolação circular no sentido horário.
# * **G03:** Interpolação circular no sentido anti-horário.
# * **G04:** Tempo de permanência.
# * **G20:** Programação em Diâmetro.
# * **G21:** Programação em Polegada.
# * **G40:** Cancela compensação do raio da ponta da ferramenta.
# * **G41:** Compensação do raio da ferramenta à esquerda.
# * **G42:** Compensação do raio da ferramenta à direita.
# * **G53:** Cancela todos os Deslocamentos de Ponto Zero.
# * **G54:** Ativa o primeiro Deslocamento de Ponto Zero.
# * **G55:** Ativa o segundo Deslocamento de Ponto Zero.
# * **G70:** Programação em Polegada.
# * **G71:** Programação em Milímetro.
# * **G73:** Interpolação Linear Ponto a ponto.
# * **G90:** Programação em Coordenadas Absolutas.
# * **G91:** Programação em Coordenadas Incrementais.
# * **G92:** Definição de Origem temporária ou Limite de RPM.
# * **G94:** Programação em Avanço por minuto.
# * **G95:** Programação em Avanço por rotação.
# * **G96:** Programação em Velocidade de Corte Constante.
# * **G97:** Programação em RPM direta.
# * **G99:** Cancela Definição de Origem Temporária.
#
# ###  Códigos Miscelâneos (Funções M)
# * **M00:** Parada programada.
# * **M02:** Fim de programa.
# * **M03:** Sentido horário de rotação do eixo-árvore.
# * **M04:** Sentido anti-horário de rotação do eixo-árvore.
# * **M05:** Desliga o eixo-árvore sem orientação.
# * **M06:** Libera o giro da Torre na troca automática de ferramentas.
# * **M07:** Liga refrigerante de corte de alta pressão.
# * **M08:** Liga refrigerante de corte de baixa pressão.
# * **M09:** Desliga refrigerante de corte.
# * **M10 a M14:** Faixas de Rotação.
# * **M24:** Abre a Placa de Fixação.
# * **M25:** Fecha a Placa de Fixação.
# * **M26:** Recua o Mangote da contra ponta.
# * **M27:** Avança o Mangote da contra ponta.
# * **M30:** Fim de programa.

# %% [markdown]
# ### Peça 01: Exercício 2 (Funções G00 e G01)
# **Desenho da Peça:**
# ![Exercício 2](exercico2.png)
#
# **Código SimTorno:**
# * **N05;** EIXO# (nome do prog.)
# * **N06** G99# (Zero Maquina)
# * **N07** M06# (Libera giro da Torre)
# * **N10** T0101# (chamada de ferramenta)
# * **N15** G54# (origem zero peça)
# * **N20** M13# (faixa de rotação)
# * **N25** G96# (Vel. Cte)
# * **N30** S400# (valor da Vc)
# * **N35** G92 S1000 M03# (limite, giro hor.)
# * **N40** G00 X80. Z80.# (ponto de troca)
# * **N50** G00 X36. Z37. M08# (1º posic.)
# * **N55** G01 X36. Z20.2 F.25# (1º corte)
# * **N60** Z37.# (1º recuo angular)
# * **N65** G00 X31. Z37.# (2º posicionamento)
# * **N70** G01 X31. Z20.2# (2º corte)
# * **N75** Z37.# (2º recuo angular)
# * **N80** G00 X26. Z37.# (3º posicionamento)
# * **N85** G01 X26. Z20.2# (3º corte)
# * **N90** Z37.# (3º recuo angular)
# * **N95** G00 X21. Z37.# (4º posicionamento)
# * **N100** G01 X21. Z20.2# (4º corte)
# * **N105** Z37.# (4º recuo angular)
# * **N110** G00 X0. Z37.# (pos. início de acab.)
# * **N115** G01 X0. Z35. F.15# (aprox. da ferr.)
# * **N120** G01 X20. Z35.# (faceamento)
# * **N125** G01 X20. Z20.# (torne. de rebaixo)
# * **N130** G01 X41. Z20.# (facea. de rebaixo)
# * **N155** G01 X41. Z12.# (torne. de diamet.)
# * **N140** X45.# (afast. ferram.)
# * **N145** G00 X80. Z80. M09# (pt, desl. fluido)
# * **N150** M30# (final de programa)

# %% [markdown]
# ---
#
# ##  3. Peças Feitas em Aula
#
# ### Peça 02: Exercício com Arcos (G02 e G03)
# **Desenho da Peça:**
# ![Peça 2](exercicio_03.png)
#
# **Código SimTorno Comentado:**
# * **N05;** G00/G01 # (Nome do programa/Tipo)
# * **N10** G99 # (Define avanço por rotação - Zero Máquina)
# * **N15** M09 # (Garante que o fluido de corte comece desligado)
# * **N20** T0101 # (Seleciona ferramenta 01 com corretor 01)
# * **N25** G54 # (Ativa o primeiro zero peça)
# * **N30** M14 # (Define a faixa de rotação)
# * **N35** G96 # (Ativa velocidade de corte constante)
# * **N40** S380 # (Define o valor da velocidade de corte)
# * **N45** G92 S3000 M03 # (Limita rotação em 3000 RPM e liga o eixo no sentido horário)
# * **N50** G00 X100. Z100. # (Posiciona no ponto de troca)
# * **N55** G00 X75. Z82. M08 # (Aproximação rápida e liga o fluido de corte)
# * **N60** G01 X75. Z25.2 F.35 # (1º Passe de desbaste longitudinal)
# * **N65** Z82. # (Recuo para início do próximo passe)
# * **N70** G00 X70. Z82. # (Posicionamento para 2º passe)
# * **N75** G01 X70. Z25.2 # (2º Passe de desbaste)
# * **N80** Z82. # (Recuo)
# * **N85** G00 X65. Z82. # (Posicionamento para 3º passe)
# * **N90** G01 X65. Z25.2 # (3º Passe de desbaste)
# * **N95** Z82. # (Recuo)
# * **N100** G00 X60. Z82. # (Posicionamento para 4º passe)
# * **N105** G01 X60. Z25.2 # (4º Passe de desbaste)
# * **N110** Z82. # (Recuo)
# * **N115** G00 X55. Z82. # (Posicionamento para 5º passe)
# * **N120** G01 X55. Z25.2 # (5º Passe de desbaste)
# * **N125** Z82. # (Recuo)
# * **N130** G00 X50. Z82. # (Posicionamento para 6º passe)
# * **N135** G01 X50. Z25.2 # (6º Passe de desbaste)
# * **N140** Z82. # (Recuo)
# * **N145** G00 X47. Z82. # (Início do desbaste do rebaixo)
# * **N150** G01 X47. Z40. # (Corte do rebaixo)
# * **N155** Z82. # (Recuo)
# * **N160** G00 X44. Z82. # (Ajuste para próximo passe do rebaixo)
# * **N165** G01 X44. Z40. # (Corte do rebaixo)
# * **N170** Z82. # (Recuo)
# * **N175** G00 X39. Z82. # (Início do desbaste da ponta)
# * **N180** G01 X39. Z50. # (Corte da ponta)
# * **N185** Z82. # (Recuo)
# * **N190** G00 X34. Z82. # (Ajuste desbaste da ponta)
# * **N195** G01 X34. Z50. # (Corte da ponta)
# * **N200** Z82. # (Recuo)
# * **N205** G00 X29. Z82. # (Ajuste desbaste da ponta)
# * **N210** G01 X29. Z50. # (Corte da ponta)
# * **N215** Z82. # (Recuo)
# * **N220** G00 X25. Z82. # (Último passe de desbaste da ponta)
# * **N225** G01 X25. Z50. # (Corte final de desbaste)
# * **N230** Z82. # (Recuo final antes do acabamento)
# * **N235** G00 X0. Z82. # (Posiciona ferramenta no centro para o acabamento)
# * **N240** G01 X0. Z80. F.20 # (Início do perfil de acabamento com avanço menor)
# * **N245** G01 X21. Z80. # (Faceamento da ponta)
# * **N250** G01 X24. Z78.5 # (Chanfro da ponta)
# * **N255** G01 X24. Z50. # (Torneamento da ponta até o início do raio)
# * **N260** G02 X44. Z40. R10. # (Interpolação circular horária - Raio de 10mm)
# * **N265** G01 X50. Z25. # (Torneamento inclinado)
# * **N270** G01 X74. Z25. # (Torneamento longitudinal)
# * **N275** G03 X80. Z22. R3. # (Interpolação circular anti-horária - Raio de 3mm)
# * **N280** G01 X80. Z12. # (Torneamento final do diâmetro maior)
# * **N285** X85. # (Afastamento radial da ferramenta)
# * **N290** G00 X100. Z100. # (Retorno ao ponto de troca)
# * **N295** M09 # (Desliga fluido de corte)
# * **N300** M05 # (Desliga o eixo-árvore)
# * **N305** M30 # (Fim do programa)
